# %%
import pandas as pd

# %%
df = pd.read_csv("/disk5/luosg/Totipotent20251031/PRJNA663159/SNV/GSM4777769_SL-3_SNV.txt.gz",sep = "\t")
df
# Out:
#      CHROM        POS         ID REF ALT QUAL FILTER GeneName        Func  \
# 0     chr1    8893964    8893964   C   T    .   PASS    Sntg1    intronic
# 1     chr1   11203857   11203857   C   A    .   PASS    Prex2    intronic
# 2     chr1   12839899   12839899   G   A    .   PASS    Sulf1      exonic
# 3     chr1   14887075   14887075   C   A    .   PASS    Trpa1    intronic
# 4     chr1   15269224   15269224   G   A    .   PASS        .  intergenic
# ...    ...        ...        ...  ..  ..  ...    ...      ...         ...
# 1808  chrX  151413995  151413995   G   T    .   PASS  Fam120c    intronic
# 1809  chrX  152240382  152240382   C   T    .   PASS    Kdm5c    intronic
# 1810  chrX  162353695  162353695   G   A    .   PASS        .  intergenic
# 1811  chrX  169368329  169368329   A   C    .   PASS        .  intergenic
# 1812  chrY   90742692   90742692   G   A    .   PASS        .  intergenic
#
#                                                   Gene  ...  \
# ...

# %%
df.columns
# Out:
# Index(['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'GeneName',
#        'Func', 'Gene', 'GeneDetail', 'ExonicFunc', 'AAChange',
#        'genomicSuperDups', 'Repeat', 'snp142chr', 'INFO', 'FORMAT', 'M_MEF',
#        'M_SL_3', 'Ori_REF', 'Ori_ALT', 'shared_hom', 'shared_het', 'OMIM',
#        'GWAS_Pubmed_pValue', 'HGMD_ID_Diseasename', 'GO_BP', 'GO_CC', 'GO_MF',
#        'KEGG_PATHWAY', 'PID_PATHWAY', 'BIOCARTA_PATHWAY', 'REACTOME_PATHWAY'],
#       dtype='object')

# %%
# Out:
# array(['.'], dtype=object)
